# %% [markdown]
# 1. Write a Python program to create a set and display its elements.
# * Input {10, 20, 30, 40}
# * Expected Output {10, 20, 30, 40} (order may vary)

# %%
a = set()
#type(a)
# a =  {10, 20, 30, 40}   # set
a.add(10)
a.add(20)
a.add(30)
a.add(40)
a
# Out:
# {10, 20, 30, 40}

# %% [markdown]
# 2. Write a Python program to add and remove elements from a set.
# * Input Set = {10, 20, 30}
# Add = 40
# Remove = 20
# * Expected Output {10, 30, 40} (order may vary)

# %%
b ={10, 20, 30}
b.add(40)
b.remove(20)
b
# Out:
# {10, 30, 40}

# %% [markdown]
# 3. Write a Python program to find the union of two sets.
# * Input A = {1, 2, 3}
# B = {3, 4, 5}
# * Expected Output {1, 2, 3, 4, 5}

# %%
A = {1, 2, 3}
B = {3, 4, 5}
A.union(B)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 4. Write a Python program to find the intersection of two sets.
# * Input A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}
# * Expected Output {3, 4}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A.intersection(B)
# Out:
# {3, 4}

# %% [markdown]
# 5. Write a Python program to find the difference between two sets.
# * Input A = {1, 2, 3, 4}
# B = {3, 4, 5}
# * Expected Output A - B = {1, 2}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5}
# A-B  this also works
A.difference(B)  #this is another way using function

#B.difference(A)  # will return {5}
#print("A - B = ", A.difference(B))
#print("B - A = ", B.difference(A))
# Out:
# {1, 2}

# %% [markdown]
# 6. Write a Python program to find the symmetric difference between two sets.
# * Input A = {1, 2, 3}
# B = {3, 4, 5}
# * Expected Output {1, 2, 4, 5}

# %%
A = {1, 2, 3}
B = {3, 4, 5}
A.symmetric_difference(B)   # returns all elements from both except common elemnts
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# 7. Write a Python program to check whether one set is a subset of another set.
# * Input A = {1, 2}
# B = {1, 2, 3, 4}
# * Expected Output A is a subset of B = True

# %%
A = {1, 2}
B = {1, 2, 3, 4}
#A.issubset(B)  # returns true or false  #A set is a subset if all its elements are present in another set
print("A is a subset of B = ", A.issubset(B))
# Out:
# A is a subset of B =  True

# %% [markdown]
# 8. Write a Python program to check whether two sets are disjoint.
# * Input A = {1, 2, 3}
# B = {4, 5, 6}
# * Expected Output The sets are disjoint = True

# %%
A = {1, 2, 3}
B = {4, 5, 6}
#A.isdisjoint(B)   # Two sets are disjoint if they have no common elements.
print("The sets are disjoint = ", A.isdisjoint(B))
# Out:
# The sets are disjoint =  True

# %% [markdown]
# 9. Write a Python program to remove duplicate elements from a list using a set.
# * Input [1, 2, 2, 3, 1, 4]
# *  Expected Output {1, 2, 3, 4}

# %%
lst = [1, 2, 2, 3, 1, 4]
set(lst)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# 10. Write a Python program to find the maximum and minimum values in a set.
# *  Input {8, 3, 15, 1, 9}
# *  Expected Output Maximum = 15, Minimum = 1

# %%
c = {8, 3, 15, 1, 9}
print("Maximum =", max(c),", Minimum =", min(c))
# Out:
# Maximum = 15 , Minimum = 1

# %% [markdown]
# 11. Write a Python program to convert a string into a set of unique characters.
# * Input banana
# *  Expected Output {'b', 'a', 'n'} (order may vary)

# %%
s = 'banana'
set(s)
# Out:
# {'a', 'b', 'n'}

# %% [markdown]
# 12. Write a Python program to count the number of elements in a set.
# *  Input {10, 20, 30, 40, 50}
# *  Expected Output Number of elements = 5

# %%
d = {10, 20, 30, 40, 50}
#len(d)

print("Number of elements = ", len(d))
# Out:
# Number of elements =  5

# %% [markdown]
# 13. Write a Python program to clear all elements from a set.
# *  Input {1, 2, 3, 4}
# *  Expected Output set()

# %%
e = {1, 2, 3, 4}
e.clear()
e
# Out:
# set()

# %% [markdown]
# 14. Write a Python program to update a set with elements from another iterable.
# * Input Set = {1, 2}
# Iterable = [3, 4, 5]
# * Expected Output {1, 2, 3, 4, 5}

# %%
f = {1, 2}
g = [3, 4, 5]
f.update(g)
f
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 15. Write a Python program to create a frozen set and demonstrate its usage.
# * Input [1, 2, 3, 4]
# * Expected Output frozenset({1, 2, 3, 4})
# Modification is not allowed.
#
#
# * **A frozenset is an immutable version of a set.
# Once created, you cannot add or remove elements from it**

# %%
h = [1, 2, 3, 4]

# Create a frozenset
frz = frozenset(h)
frz
# frz.add(5)  # will throw error can't add in frozen set
# frz.remove(1)  # will throw error can't add in frozen set
# Out:
# frozenset({1, 2, 3, 4})

# %% [markdown]
# 16. Write a Python program to find common unique words from two sentences using sets.
# * Input Sentence 1: python is easy and powerful
# Sentence 2: python is popular and useful
# * Expected Output Common words = {'python', 'is', 'and'} (order may vary)

# %%
i = 'python is easy and powerful'
j = 'python is popular and useful'
k = i.split()
l = j.split()
print(k,'  ',l)

print("Common words = ", set(k).intersection(set(l)))   # convert list into set to perform operations of sets

print("Distinct words from both sets = ", set(k).union(set(l)))
# Out:
# ['python', 'is', 'easy', 'and', 'powerful']    ['python', 'is', 'popular', 'and', 'useful']
# Common words =  {'and', 'is', 'python'}
# Distinct words from both sets =  {'python', 'useful', 'is', 'and', 'easy', 'powerful', 'popular'}
