# %% [markdown]
# 1. Write a Python program to create a list and display all its elements.
# * Input [10, 20, 30, 40]
# * Expected Output [10, 20, 30, 40]

# %%
'''
a = []
type(a)
#OR
a = list()
type(a)
'''
a = [10, 20, 30, 40]
a
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# 2. Write a Python program to find the sum and average of list elements.
# *   Input [10, 20, 30, 40]
# *   Expected Output Sum = 100, Average = 25.0

# %%
b = [10, 20, 30, 40]
sum = 0
for item in b:
  sum += item
print("Sum = ", sum, ", Average = ", sum/len(b))
# Out:
# Sum =  100 , Average =  25.0

# %% [markdown]
# 3. Write a Python program to find the largest and smallest element in a list.
# *   Input [8, 3, 15, 1, 9]
# *   Expected Output Largest = 15, Smallest = 1

# %%
b = [8, 3, 15, 1, 9]
b.sort()        # to create asending order use sort method
Largest = b[-1]
Smallest = b[0]
print("Largest = ", Largest, ", Smallest = ", Smallest)
# Out:
# Largest =  15 , Smallest =  1

# %% [markdown]
# 4. Write a Python program to count even and odd numbers in a list.
# *   Input [1, 2, 3, 4, 5, 6]
# *   Expected Output Even count = 3, Odd count = 3

# %%
c = [1, 2, 3, 4, 5, 6]
Even = 0
Odd = 0

for item in c:
  if item%2 == 0:
    Even = Even + 1
  else:
    Odd = Odd + 1
print("Even count = ", Even, ", Odd count = ", Odd)
# Out:
# Even count =  3 , Odd count =  3

# %% [markdown]
# 5. Write a Python program to remove duplicate elements from a list.
# *   Input [1, 2, 2, 3, 1, 4]
# *   Expected Output [1, 2, 3, 4]

# %%
d = [1, 2, 2, 3, 1, 4,2,3,3]
e = []
for item in d:
  if item not in e:
    e.append(item)
print('Original list', d)
print('Output list',e)
# Out:
# Original list [1, 2, 2, 3, 1, 4, 2, 3, 3]
# Output list [1, 2, 3, 4]

# %%
# using set can remove duplicate values in list
d
set(d)  # will give output in set format
list(set(d))  # convert it into list again typecasting
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 6. Write a Python program to reverse a list without using the reverse() method.
# *   Input [10, 20, 30, 40]
# *   Expected Output [40, 30, 20, 10]

# %%
f = [10, 20, 30, 40]
# using reverse method -  f.reverse()
#len(f) = 4  #index strats with o,1,2,3

reverse = []
for i in range(len(f) - 1, -1, -1):
    reverse.append(f[i])

print("Original list:", f)
print("Reversed list:", reverse)
# Out:
# Original list: [10, 20, 30, 40]
# Reversed list: [40, 30, 20, 10]

# %%
numbers = [1, 2, 3, 4, 5]

left = 0
right = len(numbers) - 1

while left < right:
    numbers[left], numbers[right] = numbers[right], numbers[left]

    left = left + 1
    right = right - 1

print(numbers)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# 7. Write a Python program to merge two lists into a single list.
# *   Input List 1 = [1, 2, 3]    List 2 = [4, 5, 6]
# *   Expected Output [1, 2, 3, 4, 5, 6]

# %%
g = [1, 2, 3]
h = [4, 5, 6]
#g.append(h)    #-- appends as it is list as a element
g.extend(h)     #-- adds seperate elements to existing list
g
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 8. Write a Python program to find the second largest number in a list.
# *   Input [10, 40, 20, 30, 50]
# *   Expected Output Second largest = 40

# %%
i = [10, 40, 20, 30, 50]
i.sort()
larg = i[-2]
print("Second largest = ", larg)
# Out:
# Second largest =  40

# %% [markdown]
# 9. Write a Python program to sort a list in ascending and descending order.
# *   Input [5, 2, 8, 1, 4]
# *   Expected Output Ascending = [1, 2, 4, 5, 8]
# Descending = [8, 5, 4, 2, 1]

# %%
j = [5, 2, 8, 1, 4]

j.sort()
print("Ascending = ", j)
#print("Ascending = ", j.sort())  ---this is not working

j.reverse()     # OR  j.sort(reverse=True)
print("Descending = ", j)
# Out:
# Ascending =  [1, 2, 4, 5, 8]
# Descending =  [8, 5, 4, 2, 1]

# %%
#this doesn't work if need to print in single line then
j = [5, 2, 8, 1, 4]
asc = j.sort()
desc = j.reverse()  # j.sort(reverse=True)
print("Ascending = ", asc , ", Descending = = ", desc)
# Out:
# Ascending =  None , Descending = =  None

# %%
# another way if need to print in single line then
asc = sorted(j)
desc = sorted(j, reverse=True)  # for descending order
print("Ascending = ", asc , ", Descending = = ", desc)
# Out:
# Ascending =  [1, 2, 4, 5, 8] , Descending = =  [8, 5, 4, 2, 1]

# %% [markdown]
# 10. Write a Python program to search for an element in a list.
# *   Input List = [10, 20, 30, 40]
# *   Search = 30
# Expected Output 30 found at index 2

# %%
k = [10, 20, 30, 40]

#num = int(input("Enter number to search : "))
num = 30
if num in k:
    print(num," found at index " , k.index(num))
else:
    print("Element not found")
# Out:
# 30  found at index  2

# %%
k = [10, 20, 30, 40]
num = int(input("Enter number to search: "))

for i in range(len(k)):
    if k[i] == num:
        print("Element found at index:", i)
        break
else:
    print("Element not found")
# Out:
# Enter number to search: 30
# Element found at index: 2

# %% [markdown]
# 11. Write a Python program to insert an element at a specific position in a list.
# *  Input List = [10, 20, 40]  Element = 30
# Position = 2
# *  Expected Output [10, 20, 30, 40]

# %%
l = [10, 20, 40]
l.insert(2,30)  # index=2, value =30
l
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# 12. Write a Python program to delete all occurrences of a given element from a list.
# *  Input List = [1, 2, 3, 2, 4, 2]
# Delete = 2
# *   Expected Output [1, 3, 4]

# %%
m =  [1, 2, 3, 2, 4, 2]
#m.remove(2)  # removes only 1st occurence

for item in m:
  if item == 2:
    m.remove(item)
m
# Out:
# [1, 3, 4]

# %%
m =  [1, 2, 3, 2, 4, 2]
deleteNum = int(input("Enter number to delete : "))

for item in m:
  if item == deleteNum:
    m.remove(item)
m
# Out:
# Enter number to delete : 2
# [1, 3, 4]

# %% [markdown]
# 13. Write a Python program to separate positive and negative numbers from a list.
# * Input [-5, 3, -2, 7, 0, -1]
# * Expected Output Positive = [3, 7]
# Negative = [-5, -2, -1]

# %%
n = [-5, 3, -2, 7, 0, -1]
positive = []
negative = []

for item in n:
  if item > 0:
    positive.append(item)
  elif item < 0:
    negative.append(item)
print("Positive = ", positive)
print("Negative = ", negative)
# Out:
# Positive =  [3, 7]
# Negative =  [-5, -2, -1]

# %% [markdown]
# 14. Write a Python program to find common elements between two lists.
# * Input List 1 = [1, 2, 3, 4]
# List 2 = [3, 4, 5, 6]
# * Expected Output Common elements = [3, 4]

# %%
o = [1, 2, 3, 4]
p = [3, 4, 5, 6]
com = []

for item in o:
  if item in p:
    com.append(item)
print("Common elements = ", com)
# Out:
# Common elements =  [3, 4]

# %%
# other way using set
cmn = list(set(o) & set(p))
cmn
# Out:
# [3, 4]

# %% [markdown]
# 15. Write a Python program to create a new list containing squares of all elements of a list.
# *  Input [1, 2, 3, 4, 5]
# *  Expected Output [1, 4, 9, 16, 25]

# %%
q = [1,2,3,4,5]
sqr =[]

for item in q:
  sqr.append(item**2)
print("Square of elements = ", sqr)
# Out:
# Square of elements =  [1, 4, 9, 16, 25]

# %% [markdown]
# 16. Write a Python program to rotate a list by n positions.
# *  Input List = [1, 2, 3, 4, 5]
# n = 2
# *  Expected Output Rotated list = [3, 4, 5, 1, 2]

# %%
r = [1, 2, 3, 4, 5]
n = 2

for item in range(n):
    temp = r.pop(0)
    r.append(temp)
print("Rotated list = ", r)
# Out:
# Rotated list =  [3, 4, 5, 1, 2]

# %%
# for single value insert at specific position

t = [1, 2, 3, 4, 5]
n = 1

element = t.pop(n)   # remove element at index 3
t.insert(4, element) # insert it at index 1
print(t)
# Out:
# [1, 3, 4, 5, 2]

# %% [markdown]
# ## Some more examples

# %%
u = []   # create list
u
# Out:
# []

# %%
u.append('rutuja')   # only single value can append at a time
u
# Out:
# ['rutuja']

# %%
u.extend('jeevika')  # append characters as different elements
u
# Out:
# ['rutuja', 'j', 'e', 'e', 'v', 'i', 'k', 'a']

# %%
v = [1, 2, 3]
w = [4, 5, 6]
v.append(8)
v
v.extend(w)
v
# Out:
# [1, 2, 3, 8, 4, 5, 6]

# %%
x = [1,2,3,4]

#pop(index=-1) by default last element removes
x.pop()
# Out:
# 4

# %%
y = ['A','B','C']
y
# Out:
# ['A', 'B', 'C']

# %%
y.insert(1,'ZZ')
y
# Out:
# ['A', 'ZZ', 'B', 'C']

# %%
y.append('SS')
y
# Out:
# ['A', 'ZZ', 'B', 'C', 'SS']

# %%
y.index('B')
# Out:
# 2

# %%
y
# Out:
# ['A', 'ZZ', 'B', 'C', 'SS']

# %% [markdown]
# # ***SECTION B - INTERMEDIATE***

# %% [markdown]
# 1. Write a Python program to remove duplicate values from a list while preserving their first occurrence.
# Input [3, 1, 3, 2, 1, 4]
# Expected Output [3, 1, 2, 4]

# %%
lst_1 = [3, 1, 3, 2, 1, 4]
unique_lst = []

for item in lst_1:
    if item not in unique_lst:
        unique_lst.append(item)

unique_lst
# Out:
# [3, 1, 2, 4]

# %% [markdown]
# 2. Write a Python program to split a list into chunks of a given size.
# Input List = [1, 2, 3, 4, 5, 6, 7, 8]
# Chunk size = 3
# Expected Output [[1, 2, 3], [4, 5, 6], [7, 8]]

# %%
list_2 = [1, 2, 3, 4, 5, 6, 7, 8]
chunk_size = 3
result = []

for i in range(0, len(list_2), chunk_size):
    result.append(list_2[i : i + chunk_size])

result
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8]]

# %% [markdown]
# 3. Write a Python program to move all zeros to the end of a list without changing the order of non-zero
# elements.
# Input [0, 1, 0, 3, 12]
# Expected Output [1, 3, 12, 0, 0]

# %%
list_3 = [0, 1, 0, 3, 12]
result = []

for item in list_3:
    if item != 0:
        result.append(item)

for item in list_3:
    if item == 0:
        result.append(item)

result
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# 4. Write a Python program to find the missing number from a list containing values from 1 to n.
# Input List = [1, 2, 4, 5, 6]
# n = 6
# Expected Output Missing number = 3

# %%
list_4 = [1, 2, 4, 5, 6]
n = 6
all_numbers = set(range(1, n + 1))
given_numbers = set(numbers)

missing = all_numbers - given_numbers
print("Missing number ",missing)
# Out:
# Missing number  {4}

# %% [markdown]
# 5. Write a Python program to find a pair of numbers whose sum is equal to a given target.
# Input List = [2, 7, 11, 15]
# Target = 9
# Expected Output Pair = (2, 7)

# %%
list_5 = [2, 7, 11, 15]
target = 9

for i in range(len(list_5)):
    for j in range(i + 1, len(list_5)):
        if list_5[i] + list_5[j] == target:
            print("Pair = ", (list_5[i], list_5[j]))
# Out:
# Pair =  (2, 7)

# %% [markdown]
# 6. Write a Python program to calculate the element-wise sum of two lists of equal length.
# Input List 1 = [1, 2, 3]
# List 2 = [4, 5, 6]
# Expected Output [5, 7, 9]

# %%
list_6 = [1, 2, 3]
list_7 = [4, 5, 6]

result = [a + b for a, b in zip(list_6, list_7)]    # using zip()

#result = list(map(lambda a, b: a + b, list_6, list_7))   # using lambda map()
result
# Out:
# [5, 7, 9]
